# %% [markdown]
# ### 1/11/22
# 1. BackendV2 Factory and Hatlab Backend
# 2. Nonglobal ops transpiler layout pass
# 3. QFT Testbench

# %%
import sys
sys.path.append("..")
import fakeutils

# %%
import numpy as np
from numpy import pi
from fakeutils.gate_map import plot_gate_map,plot_circuit_layout
from qiskit.transpiler.passes import ApplyLayout
from qiskit import QuantumCircuit
from qiskit.transpiler import PassManager

from qiskit.circuit.library.standard_gates.equivalence_library import (
    StandardEquivalenceLibrary,
)

from fakeutils.nonglobal_trivial_layout import NonGlobalTrivialLayout
from fakeutils.fakeutils import BasisTranslator

# %%
circ = QuantumCircuit(4)
circ.ry(np.pi/2, 0)
circ.rx(np.pi/2, 2)
circ.measure_active()
circ.draw(output='mpl')

# %%
from fakeutils.configurable_backend_v2 import ConfigurableFakeBackendV2
from qiskit.circuit.library.standard_gates import (
    IGate,
    RXGate,
    RYGate,
    CZGate
)
class FakeExampleV2(ConfigurableFakeBackendV2):
    """A mock backendv2"""

    def __init__(self):
        qubits = list(range(4))
        coupling_map = [[0, 1], [0, 2], [0, 3], [1, 2]]
        qubit_coordinates = [[0, 1], [1, 0], [1, 1], [1, 2]]

        gate_configuration = {}
        gate_configuration[IGate] = [(i,) for i in qubits]

        # only can do RXGates on qubits 0 and 4
        gate_configuration[RXGate] = [
            (i,) for i in list(set(qubits).difference([1, 2]))
        ]
        # can do RY on all qubits
        gate_configuration[RYGate] = [(i,) for i in qubits]

        # can do CZ on all pairs in coupling map
        gate_configuration[CZGate] = [(i, j) for i, j in coupling_map]

        # can only measure qubits 0,3
        measurable_qubits = [0, 3]

        super().__init__(
            name="mock_example",
            description="a mock backend",
            n_qubits=len(qubits),
            gate_configuration=gate_configuration,
            parameterized_gates={RXGate: "theta", RYGate: "theta"},
            measurable_qubits=measurable_qubits,
            qubit_coordinates=qubit_coordinates,
        )

        #overwrite coupling map for plotting compatability
        self.plot_coupling_map = coupling_map

backend = FakeExampleV2()

# %%
from mock_backend import LegacyFakeHatlab, FakeHatlab
hatlab_backend = FakeHatlab()
printing_backend = LegacyFakeHatlab()
plot_gate_map(printing_backend, qubit_coordinates= printing_backend.qubit_coordinates)
backend = hatlab_backend
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <module>
#       1 from mock_backend import LegacyFakeHatlab, FakeHatlab
#       2 hatlab_backend = FakeHatlab()
# ----> 3 printing_backend = LegacyFakeHatlab()
#       4 plot_gate_map(printing_backend, qubit_coordinates= printing_backend.qubit_coordinates)
#       5 backend = hatlab_backend
#
# File ~/transpilation_EM/non_global_pass/../mock_backend/fake_hatlab.py:141, in LegacyFakeHatlab.__init__(self)
#     137 coupling_map += itertools.product(range(15, 20), repeat=2)
#     139 coupling_map = [[q1, q2] for q1, q2 in coupling_map if q1 != q2]
# --> 141 super().__init__(
#     142     name="fake_hatlab",
#     143     n_qubits=20,
#     144     coupling_map=coupling_map,
#     145     basis_gates=["id", "rx", "ry", "cz", "swap"],
#     146     single_qubit_gates=["id", "rx", "ry"],
#     147 )
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/test/mock/utils/configurable_backend.py:121, in ConfigurableFakeBackend.__init__(self, name, n_qubits, version, coupling_map, basis_gates, qubit_t1, qubit_t2, qubit_frequency, qubit_readout_error, single_qubit_gates, dt, std, seed)
#     119 configuration = self._build_conf()
#     120 self._configuration = configuration
# --> 121 self._defaults = self._build_defaults()
#     122 self._properties = self._build_props()
#     124 super().__init__(configuration)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/test/mock/utils/configurable_backend.py:351, in ConfigurableFakeBackend._build_defaults(self)
#     327 for qubit1, qubit2 in self.coupling_map:
#     328     cmd_def += [
#     329         Command.from_dict(
#     330             {
#    (...)
#     348         ).to_dict()
#     349     ]
# --> 351 return PulseDefaults.from_dict(
#     352     {
#     353         "qubit_freq_est": qubit_freq_est,
#     354         "meas_freq_est": meas_freq_est,
#     355         "buffer": 0,
#     356         "pulse_library": pulse_library,
#     357         "cmd_def": cmd_def,
#     358     }
#     359 )
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/providers/models/pulsedefaults.py:279, in PulseDefaults.from_dict(cls, data)
#     277 if "discriminator" in in_data:
#     278     in_data["discriminator"] = Discriminator.from_dict(in_data.pop("discriminator"))
# --> 279 return cls(**in_data)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/providers/models/pulsedefaults.py:206, in PulseDefaults.__init__(self, qubit_freq_est, meas_freq_est, buffer, pulse_library, cmd_def, meas_kernel, discriminator, **kwargs)
#     204 self.converter = QobjToInstructionConverter(pulse_library)
#     205 for inst in cmd_def:
# --> 206     pulse_insts = [self.converter(inst) for inst in inst.sequence]
#     207     schedule = Schedule(*pulse_insts, name=inst.name)
#     208     schedule.metadata["publisher"] = CalibrationPublisher.BACKEND_PROVIDER
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/providers/models/pulsedefaults.py:206, in <listcomp>(.0)
#     204 self.converter = QobjToInstructionConverter(pulse_library)
#     205 for inst in cmd_def:
# --> 206     pulse_insts = [self.converter(inst) for inst in inst.sequence]
#     207     schedule = Schedule(*pulse_insts, name=inst.name)
#     208     schedule.metadata["publisher"] = CalibrationPublisher.BACKEND_PROVIDER
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/qobj/converters/pulse_instruction.py:443, in QobjToInstructionConverter.__call__(self, instruction)
#     441 def __call__(self, instruction):
#     442     method = self.bind_name.get_bound_method(instruction.name)
# --> 443     return method(self, instruction)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/qobj/converters/pulse_instruction.py:580, in QobjToInstructionConverter.convert_shift_phase(self, instruction)
#     578 t0 = instruction.t0
#     579 channel = self.get_channel(instruction.ch)
# --> 580 phase = self.disassemble_value(instruction.phase)
#     582 return instructions.ShiftPhase(phase, channel) << t0
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/qobj/converters/pulse_instruction.py:484, in QobjToInstructionConverter.disassemble_value(value_expr)
#     472 """A helper function to format instruction operand.
#     473
#     474 If parameter in string representation is specified, this method parses the
#    (...)
#     481     Parsed operand value. ParameterExpression object is returned if value is not number.
#     482 """
#     483 if isinstance(value_expr, str):
# --> 484     str_expr = parse_string_expr(value_expr, partial_binding=False)
#     485     value_expr = str_expr(**{pname: Parameter(pname) for pname in str_expr.params})
#     486 return value_expr
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/pulse/parser.py:326, in parse_string_expr(source, partial_binding)
#     323 for match, sub in subs:
#     324     source = source.replace(match, sub)
# --> 326 return PulseExpression(source, partial_binding)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/pulse/parser.py:87, in PulseExpression.__init__(self, source, partial_binding)
#      84         raise PulseError(f"{source} is invalid expression.") from ex
#      86 # parse parameters
# ---> 87 self.visit(self._tree)
#
# File /usr/lib/python3.8/ast.py:371, in NodeVisitor.visit(self, node)
#     369 method = 'visit_' + node.__class__.__name__
#     370 visitor = getattr(self, method, self.generic_visit)
# --> 371 return visitor(node)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/pulse/parser.py:172, in PulseExpression.visit_Expression(self, node)
#     163 def visit_Expression(self, node: ast.Expression) -> ast.Expression:
#     164     """Evaluate children nodes of expression.
#     165
#     166     Args:
#    (...)
#     170         Evaluated value.
#     171     """
# --> 172     tmp_node = copy.deepcopy(node)
#     173     tmp_node.body = self.visit(tmp_node.body)
#     175     return tmp_node
#
# File /usr/lib/python3.8/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib/python3.8/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File /usr/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File /usr/lib/python3.8/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib/python3.8/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File /usr/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
#     [... skipping similar frames: deepcopy at line 146 (9 times), _deepcopy_dict at line 230 (8 times), _reconstruct at line 270 (8 times), deepcopy at line 172 (8 times)]
#
# File /usr/lib/python3.8/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 146 (9 times), _deepcopy_dict at line 230 (8 times), _reconstruct at line 270 (8 times), deepcopy at line 172 (8 times)]
#
# File /usr/lib/python3.8/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 146 (34 times), _deepcopy_dict at line 230 (29 times), _reconstruct at line 270 (29 times), deepcopy at line 172 (29 times), _deepcopy_list at line 205 (4 times)]
#
# File /usr/lib/python3.8/copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 172 (2 times), _deepcopy_dict at line 230 (1 times), _reconstruct at line 270 (1 times), deepcopy at line 146 (1 times)]
#
# File /usr/lib/python3.8/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File /usr/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File /usr/lib/python3.8/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File /usr/lib/python3.8/copy.py:264, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     262 if deep and args:
#     263     args = (deepcopy(arg, memo) for arg in args)
# --> 264 y = func(*args)
#     265 if deep:
#     266     memo[id(x)] = y
#
# File /usr/lib/python3.8/copy.py:263, in <genexpr>(.0)
#     261 deep = memo is not None
#     262 if deep and args:
# --> 263     args = (deepcopy(arg, memo) for arg in args)
#     264 y = func(*args)
#     265 if deep:
#
# File /usr/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File /usr/lib/python3.8/copy.py:210, in _deepcopy_tuple(x, memo, deepcopy)
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#     213     try:
#
# File /usr/lib/python3.8/copy.py:210, in <listcomp>(.0)
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#     213     try:
#
# File /usr/lib/python3.8/copy.py:142, in deepcopy(x, memo, _nil)
#     139 if y is not _nil:
#     140     return y
# --> 142 cls = type(x)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
#
# KeyboardInterrupt:

# %%
layout_analysis = NonGlobalTrivialLayout(backend.target)
apply_pass = ApplyLayout()
basis_pass = BasisTranslator(StandardEquivalenceLibrary, None, target=backend.target)
pm = PassManager([layout_analysis, apply_pass, basis_pass])
circ_trans = pm.run(circ)
circ_trans.draw(output='mpl')

# %%
plot_gate_map(backend)

# %%
plot_circuit_layout(circ_trans, backend)

# %% [markdown]
# ## Demonstrate that this was broken before my transpiler pass

# %%
pm = PassManager([basis_pass])
circ_trans = pm.run(circ)
circ_trans.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# /tmp/ipykernel_185237/3041797796.py in <module>
#       1 pm = PassManager([basis_pass])
# ----> 2 circ_trans = pm.run(circ)
#       3 circ_trans.draw(output='mpl')
#
# ~/qiskit_random/github_qiskit/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py in run(self, circuits, output_name, callback)
#     216             return circuits
#     217         if isinstance(circuits, QuantumCircuit):
# --> 218             return self._run_single_circuit(circuits, output_name, callback)
#     219         if len(circuits) == 1:
#     220             return self._run_single_circuit(circuits[0], output_name, callback)
#
# ~/qiskit_random/github_qiskit/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     271         """
#     272         running_passmanager = self._create_running_passmanager()
# --> 273         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     274         self.property_set = running_passmanager.property_set
#     275         return result
#
# ~/qiskit_random/github_qiskit/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py in run(***failed resolving arguments***)
#     125         for passset in self.working_list:
#     126             for pass_ in passset:
# --> 127                 dag = self._do_pass(pass_, dag, passset.options)
#     128
#     129         circuit = dag_to_circuit(dag)
#
# ~/qiskit_random/github_qiskit/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     156         # Run the pass itself, if not already run
#     157         if pass_ not in self.valid_passes:
# --> 158             dag = self._run_this_pass(pass_, dag)
#     159
#     160             # update the valid_passes property
#
# ~/qiskit_random/github_qiskit/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     168             # Measure time if we have a callback or logging set
#     169             start_time = time()
# --> 170             new_dag = pass_.run(dag)
#     171             end_time = time()
#     172             run_time = end_time - start_time
#
# ~/qiskit_random/github_qiskit/lib/python3.8/site-packages/qiskit/transpiler/passes/basis/basis_translator.py in run(self, dag)
#     211
#     212         if basis_transforms is None:
# --> 213             raise TranspilerError(
#     214                 "Unable to map source basis {} to target basis {} "
#     215                 "over library {}.".format(source_basis, target_basis, self._equiv_lib)
#
# TranspilerError: "Unable to map source basis {('measure', 1), ('rx', 1)} to target basis {'cz', 'id', 'ry', 'snapshot', 'reset', 'barrier'} over library <qiskit.circuit.equivalence.EquivalenceLibrary object at 0x7f5a9030ee50>."

# %%
circ = QuantumCircuit(4)
circ.cz(0,1)
circ.measure_active()
circ.draw(output='mpl')

# %% [markdown]
# This is currently breaking because it does not know where to put the measure gate. Should find that CZ and measure are all valid on pair (0,3). This is not a complete solution yet still, if there is a case where it is not possible, the SWAP routing algorithms are only considering the coupling map not 1Qs or measures.

# %%
layout_analysis = NonGlobalTrivialLayout(backend.target)
apply_pass = ApplyLayout()
basis_pass = BasisTranslator(StandardEquivalenceLibrary, None, target=backend.target)
pm = PassManager([layout_analysis, apply_pass, basis_pass])
circ_trans = pm.run(circ)
circ_trans.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# Input In [13], in <module>
#       4 basis_pass = BasisTranslator(StandardEquivalenceLibrary, None, target=backend.target)
#       5 pm = PassManager([layout_analysis, apply_pass, basis_pass])
# ----> 6 circ_trans = pm.run(circ)
#       7 circ_trans.draw(output='mpl')
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py:223, in PassManager.run(self, circuits, output_name, callback)
#     221     return circuits
#     222 if isinstance(circuits, QuantumCircuit):
# --> 223     return self._run_single_circuit(circuits, output_name, callback)
#     224 if len(circuits) == 1:
#     225     return self._run_single_circuit(circuits[0], output_name, callback)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py:278, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     266 """Run all the passes on a ``circuit``.
#     267
#     268 Args:
#    (...)
#     275     The transformed circuit.
#     276 """
#     277 running_passmanager = self._create_running_passmanager()
# --> 278 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     279 self.property_set = running_passmanager.property_set
#     280 return result
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py:124, in RunningPassManager.run(***failed resolving arguments***)
#     122 for passset in self.working_list:
#     123     for pass_ in passset:
# --> 124         dag = self._do_pass(pass_, dag, passset.options)
#     126 circuit = dag_to_circuit(dag)
#     127 if output_name:
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py:155, in RunningPassManager._do_pass(self, pass_, dag, options)
#     153 # Run the pass itself, if not already run
#     154 if pass_ not in self.valid_passes:
# --> 155     dag = self._run_this_pass(pass_, dag)
#     157     # update the valid_passes property
#     158     self._update_valid_passes(pass_)
#
# File ~/transpilation_EM/venv/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py:184, in RunningPassManager._run_this_pass(self, pass_, dag)
#     181 if pass_.is_transformation_pass:
#     182     # Measure time if we have a callback or logging set
#     183     start_time = time()
# --> 184     new_dag = pass_.run(dag)
#     185     end_time = time()
#     186     run_time = end_time - start_time
#
# File ~/transpilation_EM/non_global_pass/../fakeutils/fakeutils.py:215, in BasisTranslatorFix.run(self, dag)
#     209 logger.info(
#     210     "Basis translation path search completed in %.3fs.",
#     211     search_end_time - search_start_time,
#     212 )
#     214 if basis_transforms is None:
# --> 215     raise TranspilerError(
#     216         "Unable to map source basis {} to target basis {} "
#     217         "over library {}.".format(source_basis, target_basis, self._equiv_lib)
#     218     )
#     220 # Compose found path into a set of instruction substitution rules.
#     222 compose_start_time = time.time()
#
# TranspilerError: "Unable to map source basis {('measure', 1)} to target basis {'id', 'barrier', 'snapshot', 'cz', 'reset', 'ry'} over library <qiskit.circuit.equivalence.EquivalenceLibrary object at 0x7fc391e339a0>."
