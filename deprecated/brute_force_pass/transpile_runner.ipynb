# %%
from transpile import Transpiler
import qiskit.circuit.library.standard_gates as g
import numpy as np
from circuit_ir import IR

# %%
#define custom gates
import qiskit.extensions as qe
class rootSwap(qe.UnitaryGate):
    def __init__(self):
        super().__init__(data= np.array([[1,0,0,0], [0, .5*(1+1j), .5*(1-1j), 0], [0, .5*(1-1j), .5*(1+1j), 0], [0,0,0,1]]), label=r"$\sqrt{SWAP}$")

# %%
sys.path.append("..")
import fakeutils
from fakeutils.equivalence_library import SessionEquivalenceLibrary
SessionEquivalenceLibrary.draw()
# Out:
# /home/evm9/qiskit_random/venv/lib/python3.8/site-packages/sympy/core/expr.py:3949: SymPyDeprecationWarning:
#
# expr_free_symbols method has been deprecated since SymPy 1.9. See
# https://github.com/sympy/sympy/issues/21494 for more info.
#
#   SymPyDeprecationWarning(feature="expr_free_symbols method",

# %%
# transpiler = Transpiler(gate_set = [g.IGate,g.CXGate, g.SwapGate], foobar = [rootSwap])

# %%
# #create example circuit to debug
# import qiskit.circuit.quantumcircuit as qc
# circ = qc.QuantumCircuit(2)
# circ.i(0)
# circ.i(1)
# circ.swap(0,1)
# circ.i(0)
# circ.i(1)

# %%
#create example circuit to debug
import qiskit.circuit.quantumcircuit as qc
circ = qc.QuantumCircuit(2)
circ.h(1)
circ.cnot(0,1)
circ.z(0)
circ.z(1)
circ.cnot(0,1)
circ.h(1)
print(circ)
transpiler = Transpiler(gate_set = [g.IGate,g.CXGate, g.HGate, g.ZGate, g.XGate], str_gate = ['id', 'cx', 'h', 'z'], foobar = [])
# Out:
#                ┌───┐
# q_0: ───────■──┤ Z ├──■───────
#      ┌───┐┌─┴─┐├───┤┌─┴─┐┌───┐
# q_1: ┤ H ├┤ X ├┤ Z ├┤ X ├┤ H ├
#      └───┘└───┘└───┘└───┘└───┘
# Created 439 identities from 5832 possible circuits

# %%
reduced_circ = transpiler.transpile(circ)
print(reduced_circ)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_119119/2117244405.py in <module>
# ----> 1 reduced_circ = transpiler.transpile(circ)
#       2 print(reduced_circ)
#
# ~/qiskit_random/transpile.py in transpile(self, circuit)
#      40         reduced_circuit = self._force_transpile(circuit)
#      41         # will fail if don't adjust window size
# ---> 42         temp = self._optimizeCircuit(reduced_circuit)
#      43         return temp
#      44
#
# ~/qiskit_random/transpile.py in _optimizeCircuit(self, circuit)
#      90                 # if gate_set is not None, only return circuits that contain gates from the set
#      91                 identities = self.identity_dict[finger_key]
# ---> 92                 cost_dict = self.cost_dictionary(identities)
#      93
#      94                 # use greater than because is counting number of I gates
#
# ~/qiskit_random/transpile.py in cost_dictionary(self, circuit_list)
#     136             [isinstance(gate[0], g.IGate) for gate in circ]
#     137         )
# --> 138         return [(c, _count_identity(c)) for c in self.sort_identities(circuit_list)]
#     139
#     140     def generate_circuitIdentities(self):
#
# ~/qiskit_random/transpile.py in sort_identities(self, identity_list)
#     130             [isinstance(gate[0], g.IGate) for gate in circ]
#     131         )
# --> 132         return sorted(identity_list, key=lambda x: _count_identity(x), reverse=True)
#     133
#     134     def cost_dictionary(self, circuit_list):
#
# ~/qiskit_random/transpile.py in <lambda>(x)
#     130             [isinstance(gate[0], g.IGate) for gate in circ]
#     131         )
# --> 132         return sorted(identity_list, key=lambda x: _count_identity(x), reverse=True)
#     133
#     134     def cost_dictionary(self, circuit_list):
#
# ~/qiskit_random/transpile.py in <lambda>(circ)
#     127     def sort_identities(self, identity_list):
#     128         # start simple, count number of identity gates
# --> 129         _count_identity = lambda circ: sum(
#     130             [isinstance(gate[0], g.IGate) for gate in circ]
#     131         )
#
# KeyboardInterrupt:

# %%
from qiskit.circuit.random import random_circuit
circ = random_circuit(5, 5, measure=False)
t = IR(circ)
print(t)
# Out:
# [['c;ccx', 't;ccx', 't;crz', 'c;crz', 't;ccx'], ['id', 't;cu1', 'c;cu1', 'id', 'id'], ['c;cswap', 'id', 'id', 't;cswap', 't;cswap'], ['id', 'c;cswap', 't;cswap', 't;cswap', 'id'], ['swap', 'id', 'id', 'id', 'swap'], ['t;ccx', 'id', 'c;ccx', 't;ccx', 'tdg'], ['t;cu1', 'h', 'c;cu1', 'c;ch', 't;ch']]

# %%
circ.draw(output='mpl')
