# %%
import numpy as np
from qiskit.quantum_info.operators import Operator
from qiskit.circuit.library.standard_gates import *
from qiskit import QuantumCircuit
import itertools

# %% [markdown]
# For nice target_basis, this solver won't ever find a solution because A is actually RZRY and B is actually RYRZ gates.

# %%
#search for permutatons that allow a CX gate to match the AXBXC form
#2 conditions are that ABC = 1(up to a phase), and AXBXC = X
target_basis = [RZGate(-np.pi/2), RZGate(np.pi/2), IGate(), RYGate(np.pi/2),RYGate(-np.pi/2)]

for a,b,c in itertools.permutations(target_basis, r=3):

    qc= QuantumCircuit(2)
    qc.append(a,[1])
    qc.cx(0,1)
    qc.append(b,[1])
    qc.cx(0,1)
    qc.append(c,[1])
    
    #check if equivalent up to a phase
    if Operator(qc).equiv(Operator(CXGate())):
        print(qc.draw())
        break

print("None found")
# Out:
# None found

# %% [markdown]
# Find the solution by hand and get this, but notice the solver doens't say they are equivalent unless the S is there.
#
# Despite equiv checking if equivalent up to a global phase?, this could cause problems

# %%
qc = QuantumCircuit(2)
qc.append(RZGate(np.pi/2),[1])
qc.cx(0,1)
qc.append(RZGate(-np.pi/2),[1])
qc.append(RYGate(-np.pi/2),[1])
qc.cx(0,1)
qc.append(SGate(), [0])
qc.append(RYGate(np.pi/2),[1])
qc.append(RZGate(0), [1])
print(Operator(qc).equiv(Operator(CXGate())))
qc.draw(output='mpl')
# Out:
# True

# %% [markdown]
# To convert a RY into an RZ use H,S gates

# %%
qc = QuantumCircuit(1)
theta = np.pi/4
qc.s(0)
qc.h(0)
qc.ry(theta,0)
qc.h(0)
qc.sdg(0)
print(Operator(qc).equiv(Operator(RZGate(theta))))
qc.draw(output='mpl')
# Out:
# False

# %%
a = Operator(RXGate(np.pi/2)).data * (Operator(RZGate(np.pi/3)).data * Operator(RXGate(-np.pi/2)).data)
a
# Out:
# array([[0.4330127-0.25j, 0.       +0.j  ],
#        [0.       +0.j  , 0.4330127+0.25j]])

# %%
b = Operator(RYGate(np.pi/3)).data
b
# Out:
# array([[ 0.8660254+0.j, -0.5      +0.j],
#        [ 0.5      +0.j,  0.8660254+0.j]])

# %%
Operator(a).equiv(b)
# Out:
# False

# %%
from qiskit import transpile
qc = QuantumCircuit(1)
qc.ry(np.pi/3,0)
transp = transpile(qc, basis_gates=['rx', 'rz'])
transp.draw(output='mpl')

# %%
Operator(transp).data
# Out:
# array([[ 0.8660254-5.55111512e-17j, -0.5      +0.00000000e+00j],
#        [ 0.5      +0.00000000e+00j,  0.8660254+5.55111512e-17j]])

# %%
Operator(qc).equiv(Operator(transp))
# Out:
# True

# %%
import qiskit.extensions as qe
class rootSwap(qe.UnitaryGate):
    def __init__(self):
        super().__init__(
            data=np.array(
                [
                    [1, 0, 0, 0],
                    [0, 0.5 * (1 + 1j), 0.5 * (1 - 1j), 0],
                    [0, 0.5 * (1 - 1j), 0.5 * (1 + 1j), 0],
                    [0, 0, 0, 1],
                ]
            ),
            label=r"$\sqrt{SWAP}$",
        )

temp = QuantumCircuit(2, name="cnot")
temp.cx(0,1)
temp.h(0)
temp.rz(np.pi/4,0)
temp.rz(-np.pi/4,1)
temp.h(0)
temp.h(1)
temp.cx(0,1)
temp.h(0)
temp.h(1)
temp.rz(-np.pi/4,0)
temp.h(0)
temp.cx(0,1)
temp.rz(-np.pi/2, 0)
temp.rz(np.pi/2,1)
temp.draw(output='mpl')

# %%
from sympy import init_printing
init_printing(fontsize=200)

# %%
import numpy as np 
import sympy as sym


def gen_u(label):
    a = sym.Symbol(f'alpha_{label}')
    b = sym.Symbol(f'beta_{label}')
    g = sym.Symbol(f'gamma_{label}')
    d = sym.Symbol(f'delta_{label}')
    generic_u = sym.Matrix([
        [sym.exp(1j*(a-b/2-d/2))*sym.cos(g/2),
        -1j*sym.exp(1j*(a-b/2+d/2))*sym.sin(g/2)],
        [-1j*sym.exp(1j*(a-b/2-d/2))*sym.sin(g/2),
        sym.exp(1j*(a-b/2+d/2))*sym.cos(g/2)]])
    return sym.kronecker_product(sym.eye(2),generic_u).as_explicit()

root_swap = sym.Matrix([
                    [1, 0, 0, 0],
                    [0, 0.5 * (1 + 1j), 0.5 * (1 - 1j), 0],
                    [0, 0.5 * (1 - 1j), 0.5 * (1 + 1j), 0],
                    [0, 0, 0, 1],
                ])

# %%
gen_u('A')
# Out:
# Matrix([
# [       exp(1.0*I*(alpha_A - beta_A/2 - delta_A/2))*cos(gamma_A/2), -1.0*I*exp(1.0*I*(alpha_A - beta_A/2 + delta_A/2))*sin(gamma_A/2),                                                                 0,                                                                 0],
# [-1.0*I*exp(1.0*I*(alpha_A - beta_A/2 - delta_A/2))*sin(gamma_A/2),        exp(1.0*I*(alpha_A - beta_A/2 + delta_A/2))*cos(gamma_A/2),                                                                 0,                                                                 0],
# [                                                                0,                                                                 0,        exp(1.0*I*(alpha_A - beta_A/2 - delta_A/2))*cos(gamma_A/2), -1.0*I*exp(1.0*I*(alpha_A - beta_A/2 + delta_A/2))*sin(gamma_A/2)],
# [                                                                0,                                                                 0, -1.0*I*exp(1.0*I*(alpha_A - beta_A/2 - delta_A/2))*sin(gamma_A/2),        exp(1.0*I*(alpha_A - beta_A/2 + delta_A/2))*cos(gamma_A/2)]])

# %%
gen_u('A') * root_swap * gen_u('B') * root_swap * gen_u('C')
# Out:
# ⎡    ⎛              ⎛           ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
# ⎢    ⎜              ⎜     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
# ⎢    ⎜              ⎜           ⎝       2     2 ⎠        ⎝       2     2 ⎠
# ⎢- ⅈ⋅⎜(0.5 + 0.5⋅ⅈ)⋅⎜- ⅈ⋅ℯ                       ⋅ℯ                       ⋅sin
# ⎢    ⎝              ⎝
# ⎢
# ⎢    ⎛              ⎛         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
# ⎢    ⎜              ⎜   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
# ⎢    ⎜              ⎜         ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ
# ⎢- ⅈ⋅⎜(0.5 + 0.5⋅ⅈ)⋅⎜- ℯ                       ⋅ℯ                       ⋅sin⎜─
# ⎢    ⎝              ⎝                                                       ⎝
# ⎢
# ⎢                                    ⎛              ⎛                     ⎛
# ⎢                                    ⎜              ⎜               1.0⋅ⅈ⋅⎜α_A
# ⎢                                    ⎜              ⎜                     ⎝
# ⎢                                - ⅈ⋅⎜(0.5 - 0.5⋅ⅈ)⋅⎜(0.5 + 0.5⋅ⅈ)⋅ℯ
# ⎢                                    ⎝              ⎝
# ⎢
# ⎢                                 ⎛              ⎛                         ⎛
# ⎢                                 ⎜              ⎜                   1.0⋅ⅈ⋅⎜α_
# ⎢                                 ⎜              ⎜                         ⎝
# ⎢                             - ⅈ⋅⎜(0.5 - 0.5⋅ⅈ)⋅⎜- ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ
# ⎣                                 ⎝              ⎝
#
#                                         ⎛      β_A   δ_A⎞        ⎛      β_B
#                                   1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── +
# ⎛γ_B⎞    ⎛γ_A⎞                          ⎝       2     2 ⎠        ⎝       2
# ⎜───⎟⋅cos⎜───⎟ - ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
# ⎝ 2 ⎠    ⎝ 2 ⎠
#
#                                     ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                               1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
# _A⎞    ⎛γ_B⎞                        ⎝       2     2 ⎠        ⎝       2     2 ⎠
# ──⎟⋅sin⎜───⎟ + (0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
# 2 ⎠    ⎝ 2 ⎠
#
#    β_A   δ_A⎞        ⎛      β_B   δ_B⎞                            ⎛      β_A
#  - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                      1.0⋅ⅈ⋅⎜α_A - ─── +
#     2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞          ⎝       2
#              ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟ - ℯ
#                                           ⎝ 2 ⎠    ⎝ 2 ⎠
#
#     β_A   δ_A⎞        ⎛      β_B   δ_B⎞                              ⎛      β_
# A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                        1.0⋅ⅈ⋅⎜α_A - ──
#      2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞            ⎝       2
#               ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅ℯ
#                                            ⎝ 2 ⎠    ⎝ 2 ⎠
#
# δ_B⎞                  ⎞                           ⎛      β_A   δ_A⎞        ⎛
# ───⎟                  ⎟                     1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_
#  2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟                  2        ⎝       2     2 ⎠        ⎝
#     ⋅sin⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ) ⋅ℯ                       ⋅ℯ
#         ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#                   ⎞                         ⎛      β_A   δ_A⎞        ⎛      β_
#                   ⎟                   1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ──
#     ⎛γ_A⎞    ⎛γ_B⎞⎟                2        ⎝       2     2 ⎠        ⎝       2
# ⋅cos⎜───⎟⋅cos⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ) ⋅ℯ                       ⋅ℯ
#     ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#  δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
#  ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟
#   2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
#      ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ
#                                   ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
# A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
# ─ + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟
#      2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞⎟
#         ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅(0.5 +
#                                      ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#     β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞            ⎛
# B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟            ⎜ 1.0⋅ⅈ⋅
#      2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞   ⎜
#               ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟ + ⎜ℯ
#                   ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠   ⎝
#
# B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞            ⎛           ⎛
# ─ - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟            ⎜     1.0⋅ⅈ⋅⎜α
#      2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞   ⎜           ⎝
#         ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟ + ⎜- ⅈ⋅ℯ
#             ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠   ⎝
#
#          ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
#    1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟  1.0⋅ⅈ⋅
#          ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
# )⋅ℯ                       ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                        ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#               ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
#         1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟  1
#               ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
# 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                             ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
# ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
# ⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
# ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
#                  ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟ - (0.5 + 0.5⋅ⅈ)⋅ℯ
#                                               ⎝ 2 ⎠    ⎝ 2 ⎠
#
#      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
# _A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
#                ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ
#                                             ⎝ 2 ⎠    ⎝ 2 ⎠
#
# ⎛      β_C   δ_C⎞                                   ⎛      β_A   δ_A⎞        ⎛
# ⎜α_C - ─── - ───⎟                             1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜
# ⎝       2     2 ⎠    ⎛γ_C⎞                          ⎝       2     2 ⎠        ⎝
#                  ⋅sin⎜───⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#                      ⎝ 2 ⎠
#
#      ⎛      β_C   δ_C⎞                                 ⎛      β_A   δ_A⎞
# .0⋅ⅈ⋅⎜α_C - ─── - ───⎟                           1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅
#      ⎝       2     2 ⎠    ⎛γ_C⎞                        ⎝       2     2 ⎠
#                       ⋅sin⎜───⎟ - (0.5 - 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#                           ⎝ 2 ⎠
#
#       ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛
# 1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_
#       ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝
#                        ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟⎟⋅ℯ
#                                                     ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#       ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛
# 1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_
#       ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞⎟        ⎝
#                        ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                     ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#       β_B   δ_B⎞        ⎛      β_C   δ_C⎞
# α_B - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟
#        2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞    ⎛γ_C⎞
#                 ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⋅cos⎜───⎟
#                                              ⎝ 2 ⎠    ⎝ 2 ⎠    ⎝ 2 ⎠
#
#   ⎛      β_B   δ_B⎞        ⎛      β_C   δ_C⎞
# ⅈ⋅⎜α_B - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟
#   ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞    ⎛γ_C⎞
#                    ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟
#                                                 ⎝ 2 ⎠    ⎝ 2 ⎠    ⎝ 2 ⎠
#
#     β_C   δ_C⎞           ⎛              ⎛           ⎛      β_A   δ_A⎞        ⎛
# C - ─── - ───⎟           ⎜              ⎜     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜
#      2     2 ⎠    ⎛γ_C⎞  ⎜              ⎜           ⎝       2     2 ⎠        ⎝
#               ⋅cos⎜───⎟  ⎜(0.5 + 0.5⋅ⅈ)⋅⎜- ⅈ⋅ℯ                       ⋅ℯ
#                   ⎝ 2 ⎠  ⎝              ⎝
#
#     β_C   δ_C⎞           ⎛              ⎛         ⎛      β_A   δ_A⎞        ⎛
# C - ─── - ───⎟           ⎜              ⎜   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_
#      2     2 ⎠    ⎛γ_C⎞  ⎜              ⎜         ⎝       2     2 ⎠        ⎝
#               ⋅cos⎜───⎟  ⎜(0.5 + 0.5⋅ⅈ)⋅⎜- ℯ                       ⋅ℯ
#                   ⎝ 2 ⎠  ⎝              ⎝
#
#                                                            ⎛              ⎛
#                                                            ⎜              ⎜
#                                                            ⎜              ⎜
#                                                            ⎜(0.5 - 0.5⋅ⅈ)⋅⎜(0.
#                                                            ⎝              ⎝
#
#                                                     ⎛              ⎛
#                                                     ⎜              ⎜
#                                                     ⎜              ⎜
#                                                     ⎜(0.5 - 0.5⋅ⅈ)⋅⎜- ⅈ⋅(0.5 +
#                                                     ⎝              ⎝
#
#       β_B   δ_B⎞                                            ⎛      β_A   δ_A⎞
# α_B - ─── + ───⎟                                      1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟
#        2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞                          ⎝       2     2 ⎠
#                 ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅
#                     ⎝ 2 ⎠    ⎝ 2 ⎠
#
#     β_B   δ_B⎞                                          ⎛      β_A   δ_A⎞
# B - ─── + ───⎟                                    1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0
#      2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞                        ⎝       2     2 ⎠
#               ⋅sin⎜───⎟⋅sin⎜───⎟ + (0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#                   ⎝ 2 ⎠    ⎝ 2 ⎠
#
#                   ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#             1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#                   ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
# 5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟
#                                                                 ⎝ 2 ⎠    ⎝ 2 ⎠
#
#                ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#          1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#                ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
#  0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟ -
#                                                              ⎝ 2 ⎠    ⎝ 2 ⎠
#
#        ⎛      β_B   δ_B⎞                  ⎞                           ⎛      β
#  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟                     1.0⋅ⅈ⋅⎜α_A - ─
#        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟                  2        ⎝
# ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ) ⋅ℯ
#                             ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#    ⎛      β_B   δ_B⎞                  ⎞                         ⎛      β_A   δ
# ⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟                   1.0⋅ⅈ⋅⎜α_A - ─── + ─
#    ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟                2        ⎝       2
#                     ⋅cos⎜───⎟⋅cos⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ) ⋅ℯ
#                         ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#           ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
#     1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟
#           ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
#  - ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟⎟ + (0.5
#                                                         ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#          ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
#    1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟
#          ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞⎟
# ⅈ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.
#                                                        ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
# _A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞
# ── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
# 2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠
#          ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                       ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
# _A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞
# ──⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
# 2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ
#    ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅cos⎜─
#                                 ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝
#
#                                ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                          1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
#                                ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛
#  - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅cos⎜
#                                                                              ⎝
#
#                                 ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                           1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
#                                 ⎝       2     2 ⎠        ⎝       2     2 ⎠
# 5 - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin
#
#
#               ⎛       ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#               ⎜ 1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#     ⎛γ_C⎞     ⎜       ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛
# ⋅cos⎜───⎟ - ⅈ⋅⎜ℯ                       ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜
#     ⎝ 2 ⎠     ⎝                                                     ⎝ 2 ⎠    ⎝
#
#         ⎛           ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#         ⎜     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
# _C⎞     ⎜           ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_
# ──⎟ - ⅈ⋅⎜- ⅈ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜──
# 2 ⎠     ⎝                                                         ⎝ 2 ⎠    ⎝ 2
#
#              ⎞        ⎛      β_C   δ_C⎞                                 ⎛
#              ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟                           1.0⋅ⅈ⋅⎜α_A -
# γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞                        ⎝
# ───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅cos⎜───⎟ - (0.5 - 0.5⋅ⅈ)⋅ℯ
#  2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠
#
#               ⎞        ⎛      β_C   δ_C⎞
#               ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟                                 1.0⋅ⅈ
# ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞
# ⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅cos⎜───⎟ + 1.0⋅ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅ℯ
# ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠
#
#                             ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                       1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
# γ_B⎞                        ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A
# ───⎟ - (0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin⎜───
#  2 ⎠                                                                      ⎝ 2
#
#                             ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                       1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
# B⎞                          ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B
# ─⎟ - ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin⎜───
#  ⎠                                                                        ⎝ 2
#
#  β_A   δ_A⎞        ⎛      β_B   δ_B⎞        ⎛      β_C   δ_C⎞
#  ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
#   2     2 ⎠        ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_C
#            ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───
#                                                                  ⎝ 2 ⎠    ⎝ 2
#
#  ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞        ⎛      β_C   δ_C⎞
# ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
#  ⎝       2     2 ⎠        ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞
#                   ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅
#                                                                         ⎝ 2 ⎠
#
#           ⎞        ⎛      β_C   δ_C⎞                                       ⎛
#           ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟                                       ⎜
# ⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞                              ⎜
# ⎟⋅sin⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟                              ⎜(0
# ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠                              ⎝
#
#           ⎞        ⎛      β_C   δ_C⎞
#           ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
# ⎞    ⎛γ_A⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞
# ⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟
# ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠
#
#                                                  ⎛              ⎛
#                                                  ⎜              ⎜
# ⎞    ⎛γ_A⎞                                       ⎜              ⎜
# ⎟⋅cos⎜───⎟                                       ⎜(0.5 + 0.5⋅ⅈ)⋅⎜(0.5 + 0.5⋅ⅈ)
# ⎠    ⎝ 2 ⎠                                       ⎝              ⎝
#
#                                                ⎛              ⎛
#                                                ⎜              ⎜
#    ⎛γ_B⎞    ⎛γ_C⎞                              ⎜              ⎜
# sin⎜───⎟⋅sin⎜───⎟                              ⎜(0.5 + 0.5⋅ⅈ)⋅⎜- ⅈ⋅(0.5 + 0.5⋅
#    ⎝ 2 ⎠    ⎝ 2 ⎠                              ⎝              ⎝
#
#             ⎛           ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#             ⎜     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
#             ⎜           ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞
# .5 - 0.5⋅ⅈ)⋅⎜- ⅈ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅co
#             ⎝                                                         ⎝ 2 ⎠
#
#    ⎛              ⎛         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#    ⎜              ⎜   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
#    ⎜              ⎜         ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A
#    ⎜(0.5 - 0.5⋅ⅈ)⋅⎜- ℯ                       ⋅ℯ                       ⋅sin⎜───
#    ⎝              ⎝                                                       ⎝ 2
#
#         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                      1.0⋅ⅈ⋅
#         ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
# ⋅ℯ                       ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟ - ℯ
#                                                       ⎝ 2 ⎠    ⎝ 2 ⎠
#
#           ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                        1.
#           ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
# ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅ℯ
#                                                         ⎝ 2 ⎠    ⎝ 2 ⎠
#
#                                 ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                           1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
#  ⎛γ_A⎞                          ⎝       2     2 ⎠        ⎝       2     2 ⎠
# s⎜───⎟ - ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅sin
#  ⎝ 2 ⎠
#
#                                   ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                             1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
# ⎞    ⎛γ_B⎞                        ⎝       2     2 ⎠        ⎝       2     2 ⎠
# ⎟⋅sin⎜───⎟ + (0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅c
# ⎠    ⎝ 2 ⎠
#
# ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
# ⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟
# ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟                2
#                  ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ)
#                                               ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#     ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
# 0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟
#     ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞⎟
#                      ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0
#                                                   ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#               ⎞                                        ⎛      β_A   δ_A⎞
#               ⎟                                  1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅
# ⎛γ_A⎞    ⎛γ_B⎞⎟                                        ⎝       2     2 ⎠
# ⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
# ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#                 ⎞                                      ⎛      β_A   δ_A⎞
#                 ⎟                                1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅
#   ⎛γ_A⎞    ⎛γ_B⎞⎟                                      ⎝       2     2 ⎠
# os⎜───⎟⋅cos⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#   ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛
#   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟  1.0⋅ⅈ⋅⎜
#         ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝
# ⋅ℯ                       ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                       ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#               ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞
#         1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟  1
#      2        ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
# .5⋅ⅈ) ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                             ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#   ⎛      β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞
# ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟
#   ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞
#                    ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅cos⎜───⎟ + 1.0
#                        ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠
#
#   ⎛      β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞
# ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟
#   ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞
#                    ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅cos⎜───⎟ - (0.
#                        ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠
#
#       β_C   δ_C⎞              ⎛                         ⎛      β_A   δ_A⎞
# α_C - ─── - ───⎟              ⎜                   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0
#        2     2 ⎠    ⎛γ_C⎞     ⎜                         ⎝       2     2 ⎠
#                 ⋅cos⎜───⎟ - ⅈ⋅⎜- ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#                     ⎝ 2 ⎠     ⎝
#
#      ⎛      β_C   δ_C⎞              ⎛                       ⎛      β_A   δ_A⎞
# .0⋅ⅈ⋅⎜α_C - ─── - ───⎟              ⎜                 1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟
#      ⎝       2     2 ⎠    ⎛γ_C⎞     ⎜                       ⎝       2     2 ⎠
#                       ⋅cos⎜───⎟ - ⅈ⋅⎜- (0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅
#                           ⎝ 2 ⎠     ⎝
#
#                         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞        ⎛
#                   1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_C
#                         ⎝       2     2 ⎠        ⎝       2     2 ⎠        ⎝
# ⋅ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅ℯ
#
#
#                   ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞        ⎛      β_C
#             1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_C - ───
#                   ⎝       2     2 ⎠        ⎝       2     2 ⎠        ⎝       2
# 5 - 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ                       ⋅ℯ
#
#
#    ⎛      β_B   δ_B⎞                              ⎛      β_A   δ_A⎞        ⎛
# ⋅ⅈ⋅⎜α_B - ─── + ───⎟                        1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_
#    ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞            ⎝       2     2 ⎠        ⎝
#                     ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅ℯ                       ⋅ℯ
#                         ⎝ 2 ⎠    ⎝ 2 ⎠
#
#        ⎛      β_B   δ_B⎞                            ⎛      β_A   δ_A⎞        ⎛
#  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                      1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜
#        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞          ⎝       2     2 ⎠        ⎝
# ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟ + ℯ                       ⋅ℯ
#                             ⎝ 2 ⎠    ⎝ 2 ⎠
#
#    β_C   δ_C⎞
#  - ─── - ───⎟
#     2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞    ⎛γ_C⎞
#              ⋅sin⎜───⎟⋅sin⎜───⎟⋅sin⎜───⎟
#                  ⎝ 2 ⎠    ⎝ 2 ⎠    ⎝ 2 ⎠
#
#    δ_C⎞
#  - ───⎟
#     2 ⎠    ⎛γ_B⎞    ⎛γ_C⎞    ⎛γ_A⎞
#        ⋅sin⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟
#            ⎝ 2 ⎠    ⎝ 2 ⎠    ⎝ 2 ⎠
#
#     β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞                   ⎛
# B - ─── + ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟                   ⎜
#      2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞          ⎜
#               ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟      - ⅈ⋅⎜
#                   ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠          ⎝
#
#       β_B   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞               ⎛
# α_B - ─── + ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── - ───⎟               ⎜
#        2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞      ⎜
#                 ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟  - ⅈ⋅⎜(0
#                     ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠      ⎝
#
#                            ⎛              ⎛           ⎛      β_A   δ_A⎞
#                            ⎜              ⎜     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ
#                            ⎜              ⎜           ⎝       2     2 ⎠
#                        - ⅈ⋅⎜(0.5 - 0.5⋅ⅈ)⋅⎜- ⅈ⋅ℯ                       ⋅ℯ
#                            ⎝              ⎝
#
#                              ⎛              ⎛         ⎛      β_A   δ_A⎞
#                              ⎜              ⎜   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ
#                              ⎜              ⎜         ⎝       2     2 ⎠
#                          - ⅈ⋅⎜(0.5 - 0.5⋅ⅈ)⋅⎜- ℯ                       ⋅ℯ
#                              ⎝              ⎝
#
#               ⎛                     ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#               ⎜               1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#               ⎜                     ⎝       2     2 ⎠        ⎝       2     2 ⎠
# (0.5 + 0.5⋅ⅈ)⋅⎜(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#               ⎝
#
#             ⎛                         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_
#             ⎜                   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ──
#             ⎜                         ⎝       2     2 ⎠        ⎝       2     2
# .5 + 0.5⋅ⅈ)⋅⎜- ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#             ⎝
#
#  ⎛      β_B   δ_B⎞                                            ⎛      β_A   δ_A
# ⋅⎜α_B - ─── + ───⎟                                      1.0⋅ⅈ⋅⎜α_A - ─── + ───
#  ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞                          ⎝       2     2
#                   ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ
#                       ⎝ 2 ⎠    ⎝ 2 ⎠
#
#  ⎛      β_B   δ_B⎞                                          ⎛      β_A   δ_A⎞
# ⋅⎜α_B - ─── + ───⎟                                    1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟
#  ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞                        ⎝       2     2 ⎠
#                   ⋅sin⎜───⎟⋅sin⎜───⎟ + (0.5 + 0.5⋅ⅈ)⋅ℯ                       ⋅
#                       ⎝ 2 ⎠    ⎝ 2 ⎠
#
#                             ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#                       1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#     ⎛γ_A⎞    ⎛γ_B⎞          ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A
# ⋅cos⎜───⎟⋅cos⎜───⎟ - ℯ                       ⋅ℯ                       ⋅sin⎜───
#     ⎝ 2 ⎠    ⎝ 2 ⎠                                                        ⎝ 2
#
# B⎞                              ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
# ─⎟                        1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟
#  ⎠    ⎛γ_A⎞    ⎛γ_B⎞            ⎝       2     2 ⎠        ⎝       2     2 ⎠
#   ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅ℯ                       ⋅ℯ                       ⋅sin
#       ⎝ 2 ⎠    ⎝ 2 ⎠
#
# ⎞        ⎛      β_B   δ_B⎞                  ⎞
# ⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟
# ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
#  ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ)⋅
#                               ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#        ⎛      β_B   δ_B⎞                  ⎞
#  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟                                1.0
#        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟
# ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ)⋅(0.5 + 0.5⋅ⅈ)⋅ℯ
#                             ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#           ⎞                         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#           ⎟                   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟
# ⎞    ⎛γ_B⎞⎟                2        ⎝       2     2 ⎠        ⎝       2     2 ⎠
# ⎟⋅sin⎜───⎟⎟ + (0.5 - 0.5⋅ⅈ) ⋅ℯ                       ⋅ℯ
# ⎠    ⎝ 2 ⎠⎠
#
#               ⎞                           ⎛      β_A   δ_A⎞        ⎛      β_B
#               ⎟                     1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ───
# ⎛γ_B⎞    ⎛γ_A⎞⎟                  2        ⎝       2     2 ⎠        ⎝       2
# ⎜───⎟⋅cos⎜───⎟⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ) ⋅ℯ                       ⋅ℯ
# ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#        ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛
#  1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α
#        ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝
# ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                      ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#    ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛
# ⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── - ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C -
#    ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝
#                     ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                                  ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#                   ⎞        ⎛      β_C   δ_C⎞            ⎛
#                   ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟            ⎜                   1.
#     ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞   ⎜
# ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟ + ⎜- ⅈ⋅(0.5 + 0.5⋅ⅈ)⋅ℯ
#     ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠   ⎝
#
#   δ_B⎞                  ⎞        ⎛      β_C   δ_C⎞            ⎛
# + ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟            ⎜
#    2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2     2 ⎠    ⎛γ_C⎞   ⎜
#       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ                       ⋅sin⎜───⎟ + ⎜- (0.5 + 0.5⋅ⅈ)
#           ⎝ 2 ⎠    ⎝ 2 ⎠⎠                             ⎝ 2 ⎠   ⎝
#
#      β_C   δ_C⎞                                 ⎛      β_A   δ_A⎞        ⎛
# _C - ─── + ───⎟                           1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B
#       2     2 ⎠    ⎛γ_C⎞                        ⎝       2     2 ⎠        ⎝
#                ⋅sin⎜───⎟ - (0.5 - 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#                    ⎝ 2 ⎠
#
#  β_C   δ_C⎞                                   ⎛      β_A   δ_A⎞        ⎛
#  ─── + ───⎟                             1.0⋅ⅈ⋅⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B -
#   2     2 ⎠    ⎛γ_C⎞                          ⎝       2     2 ⎠        ⎝
#            ⋅sin⎜───⎟ - ⅈ⋅(0.5 - 0.5⋅ⅈ)⋅ℯ                       ⋅ℯ
#                ⎝ 2 ⎠
#
#     ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                              ⎛
# 0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                        1.0⋅ⅈ⋅⎜α
#     ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞            ⎝
#                      ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟ - ⅈ⋅ℯ
#                                                   ⎝ 2 ⎠    ⎝ 2 ⎠
#
#         ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞
#   1.0⋅ⅈ⋅⎜α_A - ─── - ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                      1.0⋅ⅈ⋅
#         ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞
# ⋅ℯ                       ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟ + ℯ
#                                                       ⎝ 2 ⎠    ⎝ 2 ⎠
#
#   β_B   δ_B⎞        ⎛      β_C   δ_C⎞
# - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
#    2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞    ⎛γ_C⎞
#             ⋅ℯ                       ⋅sin⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟
#                                          ⎝ 2 ⎠    ⎝ 2 ⎠    ⎝ 2 ⎠
#
# β_B   δ_B⎞        ⎛      β_C   δ_C⎞
# ─── + ───⎟  1.0⋅ⅈ⋅⎜α_C - ─── + ───⎟
#  2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_B⎞    ⎛γ_A⎞    ⎛γ_C⎞
#           ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⋅cos⎜───⎟
#                                        ⎝ 2 ⎠    ⎝ 2 ⎠    ⎝ 2 ⎠
#
#      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛      β_C
# _A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ───
#       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2
#                ⋅ℯ                       ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                             ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
# ⎛      β_A   δ_A⎞        ⎛      β_B   δ_B⎞                  ⎞        ⎛      β_
# ⎜α_A - ─── + ───⎟  1.0⋅ⅈ⋅⎜α_B - ─── + ───⎟                  ⎟  1.0⋅ⅈ⋅⎜α_C - ──
# ⎝       2     2 ⎠        ⎝       2     2 ⎠    ⎛γ_A⎞    ⎛γ_B⎞⎟        ⎝       2
#                  ⋅ℯ                       ⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅ℯ
#                                               ⎝ 2 ⎠    ⎝ 2 ⎠⎠
#
#                  ⎤
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#                  ⎥
#   δ_C⎞           ⎥
# + ───⎟           ⎥
#    2 ⎠    ⎛γ_C⎞  ⎥
#       ⋅cos⎜───⎟  ⎥
#           ⎝ 2 ⎠  ⎥
#                  ⎥
# C   δ_C⎞         ⎥
# ─ + ───⎟         ⎥
#      2 ⎠    ⎛γ_C⎞⎥
#         ⋅cos⎜───⎟⎥
#             ⎝ 2 ⎠⎦
